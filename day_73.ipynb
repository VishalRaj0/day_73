# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalRaj0/day_73/blob/main/day_73.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/QueryResults.csv')
df.columns = ['DATE', 'TAG', 'POSTS']

# %%
df.count()
# Out:
# DATE     1991
# TAG      1991
# POSTS    1991
# dtype: int64

# %%
df['DATE'][0]
# Out:
# '2008-07-01 00:00:00'

# %%
from datetime import datetime

# %%
df.groupby('TAG').sum().drop('DATE', axis=1)
# Out:
#               POSTS
# TAG
# assembly      34852
# c            336042
# c#          1423530
# c++          684210
# delphi        46212
# go            47499
# java        1696403
# javascript  2056510
# perl          65286
# php         1361988
# python      1496210
# r            356799
# ruby         214582
# swift        273055

# %%
df.DATE = pd.to_datetime(df.DATE)

# %%
df.head()
# Out:
#         DATE         TAG  POSTS
# 0 2008-07-01          c#      3
# 1 2008-08-01    assembly      8
# 2 2008-08-01  javascript    162
# 3 2008-08-01           c     85
# 4 2008-08-01      python    124

# %%
test_df = pd.DataFrame({'Age': ['Young', 'Young', 'Young', 'Young', 'Old', 'Old', 'Old', 'Old'],
                        'Actor': ['Jack', 'Arnold', 'Keanu', 'Sylvester', 'Jack', 'Arnold', 'Keanu', 'Sylvester'],
                        'Power': [100, 80, 25, 50, 99, 75, 5, 30]})
test_df
# Out:
#      Age      Actor  Power
# 0  Young       Jack    100
# 1  Young     Arnold     80
# 2  Young      Keanu     25
# 3  Young  Sylvester     50
# 4    Old       Jack     99
# 5    Old     Arnold     75
# 6    Old      Keanu      5
# 7    Old  Sylvester     30

# %%
test_df.pivot(index='Age', columns='Actor', values='Power')
# Out:
# Actor  Arnold  Jack  Keanu  Sylvester
# Age
# Old        75    99      5         30
# Young      80   100     25         50

# %%
reshaped_df = df.pivot(index='DATE', columns='TAG', values='POSTS')
reshaped_df.fillna(0, inplace=True)
# Out:
# TAG         assembly       c       c#     c++  delphi     go     java  \
# DATE
# 2008-07-01       0.0     0.0      3.0     0.0     0.0    0.0      0.0
# 2008-08-01       8.0    85.0    511.0   164.0    14.0    0.0    222.0
# 2008-09-01      28.0   321.0   1649.0   755.0   105.0    0.0   1137.0
# 2008-10-01      15.0   303.0   1989.0   811.0   112.0    0.0   1153.0
# 2008-11-01      17.0   259.0   1730.0   735.0   141.0    0.0    958.0
# ...              ...     ...      ...     ...     ...    ...      ...
# 2020-03-01     317.0  2670.0   8954.0  5107.0   181.0  719.0  13253.0
# 2020-04-01     406.0  3472.0  10042.0  6820.0   250.0  887.0  15377.0
# 2020-05-01     386.0  3602.0   9923.0  7063.0   221.0  826.0  14711.0
# 2020-06-01     363.0  2757.0   9064.0  6161.0   214.0  765.0  13015.0
# 2020-07-01     298.0  2294.0   9145.0  5756.0   212.0  743.0  12723.0
#
# TAG         javascript   perl     php   python       r   ruby   swift
# DATE
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel('Date', fontsize=14)
plt.ylabel('Posts', fontsize=14)
plt.ylim(0, 35000)
for column in reshaped_df.columns:
  plt.plot(reshaped_df[column], label=column)

plt.legend(fontsize=11)

# %%
roll_df = reshaped_df.rolling(window=3).mean()

plt.figure(figsize=(12, 6))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel('Date', fontsize=14)
plt.ylabel('Posts', fontsize=14)
plt.ylim(0, 35000)
for column in roll_df.columns:
  plt.plot(roll_df[column], label=column)

plt.legend(fontsize=11)
